# %%
import os

# %%
os.getcwd()
# Out:
# 'g:\\second innings\\Python-learing-june2022'

# %%
files=os.listdir()
print(files)
# Out:
# ['.git', '.gitattributes', '.gitignore', '123.ipynb', 'assi1.ipynb', 'basic', 'basic.ipynb', 'concentricexample1.py', 'example.py', 'example2.py', 'example4circle.py', 'example5.py', 'File_andling.ipynb', 'grapexample1.py', 'graphyexample2.py', 'info.txt', 'kahani.txt', 'kahani1.txt', 'loops.ipynb', 'loops2.ipynb', 'os_module.ipynb', 'pentagan.py', 'string.ipynb', 'tuplesdic.ipynb', 'unicorn.ipynb', 'Untitled-1.py']

# %%
filesx=os.listdir("C:/Windows/System32/")
print(filesx)
# Out:
# ['0409', '@OpenWithToastLogo.png', '@TileEmpty1x1Image.png', 'accessibilitycpl.dll', 'ACCTRES.dll', 'acledit.dll', 'aclui.dll', 'acmigration.dll', 'acppage.dll', 'acproxy.dll', 'ActionCenter.dll', 'ActionCenterCPL.dll', 'ActionQueue.dll', 'activeds.dll', 'activeds.tlb', 'actxprxy.dll', 'adhapi.dll', 'adhsvc.dll', 'AdmTmpl.dll', 'adprovider.dll', 'adrclient.dll', 'adsldp.dll', 'adsldpc.dll', 'adsmsext.dll', 'adsnt.dll', 'adtschema.dll', 'AdvancedInstallers', 'advapi32.dll', 'advapi32res.dll', 'advpack.dll', 'aecache.dll', 'aeevts.dll', 'aeinv.dll', 'aelupsvc.dll', 'aepic.dll', 'AepRoam.dll', 'aitagent.exe', 'aitstatic.exe', 'alg.exe', 'AltTab.dll', 'amcompat.tlb', 'amdtee_api.dll', 'amstream.dll', 'apds.dll', 'api-ms-win-appmodel-identity-l1-1-0.dll', 'api-ms-win-appmodel-runtime-internal-l1-1-0.dll', 'api-ms-win-appmodel-runtime-l1-1-0.dll', 'api-ms-win-appmodel-runtime-l1-1-1.dll', 'api-ms-win-appmodel-state-l1-1-0.dll', 'api-ms-win-appmodel-state-l1-1-1.dll', 'api-ms-win-base-bootconfig-l1-1-0.dll', 'api-ms-win-base-util-l1-1-0.dll', 'api-ms-win-core-apiquery-l1-1-0.dll', 'api-ms-win-core-appcompat-l1-1-0.dll', 'api-ms-win-core-appcompat-l1-1-1.dll', 'api-ms-win-core-appinit-l1-1-0.dll', 'api-ms-win-core-atoms-l1-1-0.dll', 'api-ms-win-core-bem-l1-1-0.dll', 'api-ms-win-core-bicltapi-l1-1-0.dll', 'api-ms-win-core-bicltapi-l1-1-1.dll', 'api-ms-win-core-biplmapi-l1-1-0.dll', 'api-ms-win-core-biplmapi-l1-1-1.dll', 'api-ms-win-core-biptcltapi-l1-1-0.dll', 'api-ms-win-core-biptcltapi-l1-1-1.dll', 'api-ms-win-core-calendar-l1-1-0.dll', 'api-ms-win-core-com-l1-1-0.dll', 'api-ms-win-core-com-l1-1-1.dll', 'api-ms-win-core-com-private-l1-1-0.dll', 'api-ms-win-core-comm-l1-1-0.dll', 'api-ms-win-core-console-l1-1-0.dll', 'api-ms-win-core-console-l2-1-0.dll', 'api-ms-win-core-crt-l1-1-0.dll', 'api-ms-win-core-crt-l2-1-0.dll', 'api-ms-win-core-datetime-l1-1-0.dll', 'api-ms-win-core-datetime-l1-1-1.dll', 'api-ms-win-core-debug-l1-1-0.dll', 'api-ms-win-core-debug-l1-1-1.dll', 'api-ms-win-core-delayload-l1-1-0.dll', 'api-ms-win-core-delayload-l1-1-1.dll', 'api-ms-win-core-errorhandling-l1-1-0.dll', 'api-ms-win-core-errorhandling-l1-1-1.dll', 'api-ms-win-core-fibers-l1-1-0.dll', 'api-ms-win-core-fibers-l1-1-1.dll', 'api-ms-win-core-fibers-l2-1-0.dll', 'api-ms-win-core-fibers-l2-1-1.dll', 'api-ms-win-core-file-l1-1-0.dll', 'api-ms-win-core-file-l1-2-0.dll', 'api-ms-win-core-file-l1-2-1.dll', 'api-ms-win-core-file-l2-1-0.dll', 'api-ms-win-core-file-l2-1-1.dll', 'api-ms-win-core-firmware-l1-1-0.dll', 'api-ms-win-core-handle-l1-1-0.dll', 'api-ms-win-core-heap-l1-1-0.dll', 'api-ms-win-core-heap-l1-2-0.dll', 'api-ms-win-core-heap-obsolete-l1-1-0.dll', 'api-ms-win-core-interlocked-l1-1-0.dll', 'api-ms-win-core-interlocked-l1-2-0.dll', 'api-ms-win-core-io-l1-1-0.dll', 'api-ms-win-core-io-l1-1-1.dll', 'api-ms-win-core-job-l1-1-0.dll', 'api-ms-win-core-job-l2-1-0.dll', 'api-ms-win-core-kernel32-legacy-l1-1-0.dll', 'api-ms-win-core-kernel32-legacy-l1-1-1.dll', 'api-ms-win-core-kernel32-private-l1-1-0.dll', 'api-ms-win-core-libraryloader-l1-1-0.dll', 'api-ms-win-core-libraryloader-l1-1-1.dll', 'api-ms-win-core-libraryloader-l1-2-0.dll', 'api-ms-win-core-libraryloader-private-l1-1-0.dll', 'api-ms-win-core-localization-l1-1-0.dll', 'api-ms-win-core-localization-l1-2-0.dll', 'api-ms-win-core-localization-l1-2-1.dll', 'api-ms-win-core-localization-l2-1-0.dll', 'api-ms-win-core-localization-obsolete-l1-1-0.dll', 'api-ms-win-core-localization-obsolete-l1-2-0.dll', 'api-ms-win-core-localization-private-l1-1-0.dll', 'api-ms-win-core-localregistry-l1-1-0.dll', 'api-ms-win-core-memory-l1-1-0.dll', 'api-ms-win-core-memory-l1-1-1.dll', 'api-ms-win-core-memory-l1-1-2.dll', 'api-ms-win-core-multipleproviderrouter-l1-1-0.dll', 'api-ms-win-core-namedpipe-l1-1-0.dll', 'api-ms-win-core-namedpipe-l1-2-0.dll', 'api-ms-win-core-namespace-l1-1-0.dll', 'api-ms-win-core-normalization-l1-1-0.dll', 'api-ms-win-core-path-l1-1-0.dll', 'api-ms-win-core-privateprofile-l1-1-0.dll', 'api ...

# %%
x=len(filesx)

# %%
print(x)
# Out:
# 3721

# %%
dlls=0
for file in filesx:
    if file.endswith('.dll'):
        dlls+=1
print(f'the system has {dlls} dlls ')
# Out:
# the system has 2578 dlls

# %%
os.mkdir('basic')

# %%
os.mkdir("faltu_folder")

# %%
os.rmdir('faltu_folder')

# %%
os.path.isdir('basic')
# Out:
# True

# %%
for item in files:
    if os.path.isdir(item):
        print(f'{item} is Directory')
# Out:
# .git is Directory
# basic is Directory

# %%
os.path.getsize(r'C:\Users\Ankit Shrivastava\Downloads\VSCodeSetup-x64-1.67.2.exe')
# Out:
# 79513048

# %%
files=os.listdir()
for item in files:
    if os.path.isfile(item):
        sz=os.path.getsize(item)
        print(f'{item.ljust(25)} | {sz/1024 :.1f} kb ')
# Out:
# .gitattributes            | 0.1 kb
# .gitignore                | 2.8 kb
# 123.ipynb                 | 0.4 kb
# assi1.ipynb               | 9.4 kb
# basic.ipynb               | 40.4 kb
# concentricexample1.py     | 0.3 kb
# example.py                | 0.1 kb
# example2.py               | 0.1 kb
# example4circle.py         | 0.2 kb
# example5.py               | 0.2 kb
# File_andling.ipynb        | 2176.5 kb
# grapexample1.py           | 0.3 kb
# graphyexample2.py         | 0.3 kb
# info.txt                  | 0.0 kb
# kahani.txt                | 0.1 kb
# kahani1.txt               | 0.0 kb
# loops.ipynb               | 11362.7 kb
# loops2.ipynb              | 4.1 kb
# os_module.ipynb           | 78.8 kb
# pentagan.py               | 0.1 kb
# string.ipynb              | 18.7 kb
# tuplesdic.ipynb           | 21.3 kb
# unicorn.ipynb             | 3.3 kb
# Untitled-1.py             | 2.4 kb

# %%
folder="c:/windows/system32/"
files=os.listdir(folder)
for item in files:
    fullpath=os.path.join(folder,item)
    if os.path.isfile(fullpath):
        sz=os.path.getsize(fullpath)
        print(f'{item.ljust(70)} | {sz/1024 :.1f} kb')
# Out:
# @OpenWithToastLogo.png                                                 | 0.2 kb
# @TileEmpty1x1Image.png                                                 | 0.1 kb
# accessibilitycpl.dll                                                   | 3725.0 kb
# ACCTRES.dll                                                            | 38.5 kb
# acledit.dll                                                            | 10.0 kb
# aclui.dll                                                              | 1014.0 kb
# acmigration.dll                                                        | 294.0 kb
# acppage.dll                                                            | 54.5 kb
# acproxy.dll                                                            | 12.0 kb
# ActionCenter.dll                                                       | 874.0 kb
# ActionCenterCPL.dll                                                    | 533.5 kb
# ActionQueue.dll                                                        | 224.5 kb
# activeds.dll                                                           | 272.0 kb
# activeds.tlb                                                           | 109.0 kb
# actxprxy.dll                                                           | 2814.0 kb
# adhapi.dll                                                             | 22.5 kb
# adhsvc.dll                                                             | 76.0 kb
# AdmTmpl.dll                                                            | 569.0 kb
# adprovider.dll                                                         | 57.0 kb
# adrclient.dll                                                          | 133.0 kb
# adsldp.dll                                                             | 268.0 kb
# adsldpc.dll                                                            | 245.5 kb
# adsmsext.dll                                                           | 101.0 kb
# adsnt.dll                                                              | 346.5 kb
# adtschema.dll                                                          | 739.0 kb
# advapi32.dll                                                           | 669.4 kb
# advapi32res.dll                                                        | 2.0 kb
# advpack.dll                                                            | 139.5 kb
# aecache.dll                                                            | 41.5 kb
# aeevts.dll                                                             | 28.5 kb
# aeinv.dll                                                              | 665.0 kb
# aelupsvc.dll                                                           | 209.5 kb
# aepic.dll                                                              | 240.5 kb
# AepRoam.dll                                                            | 63.5 kb
# aitagent.exe                                                           | 153.5 kb
# aitstatic.exe                                                          | 2793.0 kb
# alg.exe                                                                | 94.5 kb
# AltTab.dll                                                             | 115.5 kb
# amcompat.tlb                                                           | 18.0 kb
# amdtee_api.dll                                                         | 28.0 kb
# amstream.dll                                                           | 98.0 kb
# apds.dll                                                               | 261.0 kb
# api-ms-win-appmodel-identity-l1-1-0.dll                                | 3.0 kb
# api-ms-win-appmodel-runtime-internal-l1-1-0.dll                        | 3.5 kb
# api-ms-win-appmodel-runtime-l1-1-0.dll                                 | 3.0 kb
# api-ms-win-appmodel-runtime-l1-1-1.dll                                 | 3.5 kb
# api-ms-win-appmodel-state-l1-1-0.dll                                   | 4.0 kb
# api-ms-win-appmodel-state-l1-1-1.dll                                   | 4.0 kb
# api-ms-win-base-bootconfig-l1-1-0.dll                                  | 3.0 kb
# api-ms-win-base-util-l1-1-0.dll                                        | 3.0 kb
# api-ms-win-core-apiquery-l1-1-0.dll                                    | 2.5 kb
# api-ms-win-core-appcompat-l1-1-0.dll                                   | 3.5 kb
# api-ms-win-core-appcompat-l1-1-1.dll                                   | 3.5 kb
# api-ms-win-core-appinit-l1-1-0.dll                                     | 2.5 kb
# api-ms-win-core-atoms-l1-1-0.dll                                       | 3.5 kb
# api-ms-win-core-bem-l1-1-0.dll                                         | 2.5 kb
# api-ms-win-core-bicltapi-l1-1-0.dll                                    | 3.5 kb
# api-ms-win-core-bicltapi-l1-1-1.dll                                    | 3.5 kb
# api-ms-win-core-biplmapi-l1-1-0.dll                                    | 3.0 kb
# api-ms-win-core-biplmapi-l1-1-1.dll                                    | 3.5 kb
# api-ms-win-core-biptcltapi-l1-1-0.dll                                  | 3.5 kb
# api-ms-win-core-biptcltapi-l1-1-1.dll                                  | 3.5 kb
# api-ms-win-core-calendar-l1-1-0.dll                                    | 3.0 kb
# api-ms-win-core-com-l1-1-0.dll                                         | 5.5 kb
# api-ms-win-core-com-l1-1-1.dll                                         | 5.5 kb
# api-ms-win-core-com-private-l1-1-0.dll                                 | 6.0 kb
# api-ms-win-core-comm-l1-1-0.dll                                        | 3.5 kb
# api-ms-win-core-console-l1-1-0.dll                                     | 3.5 kb
# api-ms-win-core-console-l2-1-0.dll                                     | 4.0 kb
# api-ms-win-core-crt-l1-1-0.dll                                         | 4.5 kb
# api-ms-win-core-crt-l2-1-0.dll                                         | 3.0 kb
# api-ms-win-core-datetime-l1-1-0.dll                                    | 2.5 kb
# api-ms-win-core-datetime-l1-1-1.dll                                    | 2.5 kb
# api-ms-win-core-debug-l1-1-0.dll                                       | 2.5 kb
# api-ms-win-core-debug-l1-1-1.dll                                       | 2.5 kb
# api-ms-win-core-delayload-l1-1-0.dll                                   | 2.5 kb
# api-ms-win-core-delayload-l1-1-1.dll                                   | 2.5 kb
# api-ms-win-core-errorhandling-l1-1-0.dll                               | 2.5 kb
# api-ms-win-core-errorhandling-l1-1-1.dll                               | 3.0 kb
# api-ms-win-core-fibers-l1-1-0.dll                                      | 2.5 kb
# api-ms-win-core-fibers-l1-1-1.dll                                      | 2.5 kb
# api-ms-win-core-fibers-l2-1-0.dll                                      | 3.0 kb
# api-ms-win-core-fibers-l2-1-1.dll                                      | 3.0 kb
# api-ms-win-core-file-l1-1-0.dll                                        | 4.5 kb
# api-ms-win-core-file-l1-2-0.dll                                        | 4.5 kb
# api-ms-win-core-file-l1-2-1.dll                                        | 4.5 kb
# api-ms-win-core-file-l2-1-0.dll                                        | 2.5 kb
# api-ms-win-core-file-l2-1-1.dll                                        | 3.0 kb
# api-ms-win-core-firmware-l1-1-0.dll                                    | 2.5 kb
# api-ms-win-core-handle-l1-1-0.dll                                      | 2.5 kb
# api-ms-win-core-heap-l1-1-0.dll                                        | 3.0 kb
# api-ms-win-core-heap-l1-2-0.dll                                        | 3.0 kb
# api-ms-win-core-heap-obsolete-l1-1-0.dll                               | 3.5 kb
# api-ms-win-core-interlocked-l1-1-0.dll                                 | 2.5 kb
# api-ms-win-core-interlocked-l1-2-0.dll                                 | 2.5 kb
# api-ms-win-core-io-l1-1-0.dll                                          | 2.5 kb
# api-ms-win-core-io-l1-1-1.dll                                          | 3.0 kb
# api-ms-win-core-job-l1-1-0.dll                                         | 2.5 kb
# api-ms-win-core-job-l2-1-0.dll                                         | 2.5 kb
# api-ms-win-core-kernel32-legacy-l1-1-0.dll                             | 4.5 kb
# api-ms-win-core-kernel32-legacy-l1-1-1.dll                             | 5.0 kb
# api-ms-win-core-kernel32-private-l1-1-0.dll                            | 3.5 kb
# api-ms-win-core-libraryloader-l1-1-0.dll                               | 3.5 kb
# api-ms-win-core-libraryloader-l1-1-1.dll                               | 3.5 kb
# api-ms-win-core-libraryloader-l1-2-0.dll                               | 3.5 kb
# api-ms-win-core-libraryloader-private-l1-1-0.dll                       | 2.5 kb
# api-ms-win-core-localization-l1-1-0.dll                                | 4.0 kb
# api-ms-win-core-localization-l1-2-0.dll                                | 4.0 kb
# api-ms-win-core-localization-l1-2-1.dll                                | 4.0 kb
# api-ms-win-core-localization-l2-1-0.dll                                | 3.0 kb
# api-ms-win-core-localization-obsolete-l1-1-0.dll                       | 3.0 kb
# api-ms-win-core-localization-obsolete-l1-2-0.dll                       | 3.0 kb
# api-ms-win-core-localization-private-l1-1-0.dll                        | 3.0 kb
# api-ms-win-core-localregistry-l1-1-0.dll                               | 3.5 kb
# api-ms-win-core-memory-l1-1-0.dll                                      | 3.0 kb
# api-ms-win-core-memory-l1-1-1.dll                                      | 3.5 kb
# api-ms-win-core-memory-l1-1-2.dll                                      | 3.5 kb
# api-ms-win-core-multipleproviderrouter-l1-1-0.dll                      | 3.0 kb
# api-ms-win-core-namedpipe-l1-1-0.dll                                   | 3.0 kb
# api-ms-win-core-namedpipe-l1-2-0.dll                                   | 3.0 kb
# api-ms-win-core-namespace-l1-1-0.dll                                   | 2.5 kb
# api-ms-win-core-normalization-l1-1-0.dll                               | 2.5 kb
# api-ms-win-core-path-l1-1-0.dll                                        | 3.0 kb
# api-ms-win-core-privateprofile-l1-1-0.dll                              | 3.5 kb
# api-ms-win-core-processenvironment-l1-1-0.dll                          | 3.5 kb
# api-ms-win-core-processenvironment-l1-2-0.dll                          | 3.5 kb
# api-ms-win-core-processsecurity-l1-1-0.dll                             | 2.5 kb
# api-ms-win-core-processthreads-l1-1-0.dll                              | 4.0 kb
# api-ms-win-core-processthreads-l1-1-1.dll                              | 4.5 kb
# api-ms-win-core-processthreads-l1-1-2.dll                              | 4.5 kb
# api-ms-win-core-processtopology-l1-1-0.dll                             | 2.5 kb
# api-ms-win-core-processtopology-l1-2-0.dll                             | 2.5 kb
# api-ms-win-core-processtopology-obsolete-l1-1-0.dll                    | 2.5 kb
# api-ms-win-core-processtopology-private-l1-1-0.dll                     | 2.5 kb
# api-ms-win-core-profile-l1-1-0.dll                                     | 2.5 kb
# api-ms-win-core-psapi-ansi-l1-1-0.dll                                  | 2.5 kb
# api-ms-win-core-psapi-l1-1-0.dll                                       | 3.0 kb
# api-ms-win-core-psapi-obsolete-l1-1-0.dll                              | 2.5 kb
# api-ms-win-core-psm-app-l1-1-0.dll                                     | 3.0 kb
# api-ms-win-core-psm-appnotify-l1-1-0.dll                               | 2.5 kb
# api-ms-win-core-psm-info-l1-1-0.dll                                    | 3.0 kb
# api-ms-win-core-psm-key-l1-1-0.dll                                     | 3.0 kb
# api-ms-win-core-psm-plm-l1-1-0.dll                                     | 3.0 kb
# api-ms-win-core-psm-plm-l1-1-1.dll                                     | 3.5 kb
# api-ms-win-core-quirks-l1-1-0.dll                                      | 3.0 kb
# api-ms-win-core-realtime-l1-1-0.dll                                    | 2.5 kb
# api-ms-win-core-registry-l1-1-0.dll                                    | 3.5 kb
# api-ms-win-core-registry-l2-1-0.dll                                    | 4.0 kb
# api-ms-win-core-registry-private-l1-1-0.dll                            | 3.0 kb
# api-ms-win-core-registryuserspecific-l1-1-0.dll                        | 3.0 kb
# api-ms-win-core-rtlsupport-l1-1-0.dll                                  | 3.0 kb
# api-ms-win-core-rtlsupport-l1-2-0.dll                                  | 3.0 kb
# api-ms-win-core-shlwapi-legacy-l1-1-0.dll                              | 5.0 kb
# api-ms-win-core-shlwapi-obsolete-l1-1-0.dll                            | 3.5 kb
# api-ms-win-core-shutdown-l1-1-0.dll                                    | 3.0 kb
# api-ms-win-core-sidebyside-l1-1-0.dll                                  | 3.0 kb
# api-ms-win-core-string-l1-1-0.dll                                      | 2.5 kb
# api-ms-win-core-string-l2-1-0.dll                                      | 2.5 kb
# api-ms-win-core-string-obsolete-l1-1-0.dll                             | 3.0 kb
# api-ms-win-core-stringansi-l1-1-0.dll                                  | 2.5 kb
# api-ms-win-core-stringloader-l1-1-0.dll                                | 2.5 kb
# api-ms-win-core-stringloader-l1-1-1.dll                                | 2.5 kb
# api-ms-win-core-synch-l1-1-0.dll                                       | 3.5 kb
# api-ms-win-core-synch-l1-2-0.dll                                       | 4.0 kb
# api-ms-win-core-sysinfo-l1-1-0.dll                                     | 3.5 kb
# api-ms-win-core-sysinfo-l1-2-0.dll                                     | 3.5 kb
# api-ms-win-core-sysinfo-l1-2-1.dll                                     | 3.5 kb
# api-ms-win-core-systemtopology-l1-1-0.dll                              | 2.5 kb
# api-ms-win-core-threadpool-l1-1-0.dll                                  | 4.0 kb
# api-ms-win-core-threadpool-l1-2-0.dll                                  | 4.0 kb
# api-ms-win-core-threadpool-legacy-l1-1-0.dll                           | 2.5 kb
# api-ms-win-core-threadpool-private-l1-1-0.dll                          | 2.5 kb
# api-ms-win-core-timezone-l1-1-0.dll                                    | 3.0 kb
# api-ms-win-core-timezone-private-l1-1-0.dll                            | 2.5 kb
# api-ms-win-core-toolhelp-l1-1-0.dll                                    | 3.0 kb
# api-ms-win-core-ums-l1-1-0.dll                                         | 3.5 kb
# api-ms-win-core-url-l1-1-0.dll                                         | 3.5 kb
# api-ms-win-core-util-l1-1-0.dll                                        | 2.5 kb
# api-ms-win-core-version-l1-1-0.dll                                     | 2.5 kb
# api-ms-win-core-version-private-l1-1-0.dll                             | 2.5 kb
# api-ms-win-core-versionansi-l1-1-0.dll                                 | 2.5 kb
# api-ms-win-core-windowserrorreporting-l1-1-0.dll                       | 3.0 kb
# api-ms-win-core-winrt-error-l1-1-0.dll                                 | 3.5 kb
# api-ms-win-core-winrt-error-l1-1-1.dll                                 | 3.5 kb
# api-ms-win-core-winrt-errorprivate-l1-1-0.dll                          | 3.0 kb
# api-ms-win-core-winrt-errorprivate-l1-1-1.dll                          | 3.0 kb
# api-ms-win-core-winrt-l1-1-0.dll                                       | 3.5 kb
# api-ms-win-core-winrt-propertysetprivate-l1-1-0.dll                    | 3.0 kb
# api-ms-win-core-winrt-registration-l1-1-0.dll                          | 3.0 kb
# api-ms-win-core-winrt-robuffer-l1-1-0.dll                              | 3.0 kb
# api-ms-win-core-winrt-roparameterizediid-l1-1-0.dll                    | 3.0 kb
# api-ms-win-core-winrt-string-l1-1-0.dll                                | 4.0 kb
# api-ms-win-core-wow64-l1-1-0.dll                                       | 2.5 kb
# api-ms-win-core-xstate-l1-1-0.dll                                      | 3.0 kb
# api-ms-win-core-xstate-l1-1-1.dll                                      | 3.5 kb
# api-ms-win-core-xstate-l2-1-0.dll                                      | 2.5 kb
# api-ms-win-crt-conio-l1-1-0.dll                                        | 12.3 kb
# api-ms-win-crt-convert-l1-1-0.dll                                      | 15.3 kb
# api-ms-win-crt-environment-l1-1-0.dll                                  | 11.8 kb
# api-ms-win-crt-filesystem-l1-1-0.dll                                   | 13.3 kb
# api-ms-win-crt-heap-l1-1-0.dll                                         | 12.3 kb
# api-ms-win-crt-locale-l1-1-0.dll                                       | 11.8 kb
# api-ms-win-crt-math-l1-1-0.dll                                         | 20.3 kb
# api-ms-win-crt-multibyte-l1-1-0.dll                                    | 19.3 kb
# api-ms-win-crt-private-l1-1-0.dll                                      | 62.3 kb
# api-ms-win-crt-process-l1-1-0.dll                                      | 12.3 kb
# api-ms-win-crt-runtime-l1-1-0.dll                                      | 15.8 kb
# api-ms-win-crt-stdio-l1-1-0.dll                                        | 17.3 kb
# api-ms-win-crt-string-l1-1-0.dll                                       | 17.3 kb
# api-ms-win-crt-time-l1-1-0.dll                                         | 13.8 kb
# api-ms-win-crt-utility-l1-1-0.dll                                      | 11.8 kb
# api-ms-win-devices-config-l1-1-0.dll                                   | 4.5 kb
# api-ms-win-devices-config-l1-1-1.dll                                   | 4.5 kb
# api-ms-win-devices-query-l1-1-0.dll                                    | 3.0 kb
# api-ms-win-devices-query-l1-1-1.dll                                    | 3.0 kb
# api-ms-win-devices-swdevice-l1-1-0.dll                                 | 2.5 kb
# api-ms-win-devices-swdevice-l1-1-1.dll                                 | 2.5 kb
# api-ms-win-downlevel-advapi32-l1-1-0.dll                               | 6.5 kb
# api-ms-win-downlevel-advapi32-l1-1-1.dll                               | 7.0 kb
# api-ms-win-downlevel-advapi32-l2-1-0.dll                               | 3.5 kb
# api-ms-win-downlevel-advapi32-l2-1-1.dll                               | 5.0 kb
# api-ms-win-downlevel-advapi32-l3-1-0.dll                               | 2.5 kb
# api-ms-win-downlevel-advapi32-l4-1-0.dll                               | 3.5 kb
# api-ms-win-downlevel-kernel32-l1-1-0.dll                               | 20.5 kb
# api-ms-win-downlevel-kernel32-l2-1-0.dll                               | 5.5 kb
# api-ms-win-downlevel-normaliz-l1-1-0.dll                               | 2.5 kb
# api-ms-win-downlevel-ole32-l1-1-0.dll                                  | 4.5 kb
# api-ms-win-downlevel-ole32-l1-1-1.dll                                  | 5.0 kb
# api-ms-win-downlevel-shell32-l1-1-0.dll                                | 3.0 kb
# api-ms-win-downlevel-shlwapi-l1-1-0.dll                                | 6.0 kb
# api-ms-win-downlevel-shlwapi-l1-1-1.dll                                | 6.5 kb
# api-ms-win-downlevel-shlwapi-l2-1-0.dll                                | 4.5 kb
# api-ms-win-downlevel-shlwapi-l2-1-1.dll                                | 4.0 kb
# api-ms-win-downlevel-user32-l1-1-0.dll                                 | 3.5 kb
# api-ms-win-downlevel-user32-l1-1-1.dll                                 | 3.0 kb
# api-ms-win-downlevel-version-l1-1-0.dll                                | 2.5 kb
# api-ms-win-dx-d3dkmt-l1-1-0.dll                                        | 6.5 kb
# api-ms-win-eventing-classicprovider-l1-1-0.dll                         | 2.5 kb
# api-ms-win-eventing-consumer-l1-1-0.dll                                | 2.5 kb
# api-ms-win-eventing-controller-l1-1-0.dll                              | 3.0 kb
# api-ms-win-eventing-legacy-l1-1-0.dll                                  | 3.0 kb
# api-ms-win-eventing-obsolete-l1-1-0.dll                                | 2.5 kb
# api-ms-win-eventing-provider-l1-1-0.dll                                | 2.5 kb
# api-ms-win-eventlog-legacy-l1-1-0.dll                                  | 2.5 kb
# api-ms-win-eventlog-private-l1-1-0.dll                                 | 3.0 kb
# api-ms-win-gdi-dpiinfo-l1-1-0.dll                                      | 3.0 kb
# api-ms-win-http-time-l1-1-0.dll                                        | 2.5 kb
# api-ms-win-input-ie-interactioncontext-l1-1-0.dll                      | 4.0 kb
# api-ms-win-mm-joystick-l1-1-0.dll                                      | 3.0 kb
# api-ms-win-mm-mci-l1-1-0.dll                                           | 3.5 kb
# api-ms-win-mm-misc-l1-1-0.dll                                          | 3.5 kb
# api-ms-win-mm-misc-l1-1-1.dll                                          | 3.5 kb
# api-ms-win-mm-misc-l2-1-0.dll                                          | 3.0 kb
# api-ms-win-mm-mme-l1-1-0.dll                                           | 5.5 kb
# api-ms-win-mm-playsound-l1-1-0.dll                                     | 3.0 kb
# api-ms-win-mm-time-l1-1-0.dll                                          | 3.0 kb
# api-ms-win-net-isolation-l1-1-0.dll                                    | 3.0 kb
# api-ms-win-net-isolation-l1-1-1.dll                                    | 3.0 kb
# api-ms-win-ntuser-ie-message-l1-1-0.dll                                | 3.5 kb
# api-ms-win-ntuser-ie-window-l1-1-0.dll                                 | 4.5 kb
# api-ms-win-ntuser-ie-wmpointer-l1-1-0.dll                              | 3.5 kb
# api-ms-win-oobe-notification-l1-1-0.dll                                | 2.5 kb
# api-ms-win-perf-legacy-l1-1-0.dll                                      | 3.0 kb
# api-ms-win-power-base-l1-1-0.dll                                       | 3.0 kb
# api-ms-win-power-setting-l1-1-0.dll                                    | 3.0 kb
# api-ms-win-ro-typeresolution-l1-1-0.dll                                | 3.0 kb
# api-ms-win-rtcore-navigation-l1-1-0.dll                                | 3.0 kb
# api-ms-win-rtcore-ntuser-clipboard-l1-1-0.dll                          | 3.5 kb
# api-ms-win-rtcore-ntuser-private-l1-1-0.dll                            | 3.5 kb
# api-ms-win-rtcore-ntuser-synch-l1-1-0.dll                              | 3.0 kb
# api-ms-win-rtcore-ntuser-window-l1-1-0.dll                             | 5.0 kb
# api-ms-win-rtcore-ntuser-windowstation-l1-1-0.dll                      | 3.5 kb
# api-ms-win-rtcore-ntuser-winevent-l1-1-0.dll                           | 3.0 kb
# api-ms-win-rtcore-ntuser-wmpointer-l1-1-0.dll                          | 4.0 kb
# api-ms-win-rtcore-ole32-clipboard-l1-1-0.dll                           | 3.0 kb
# api-ms-win-rtcore-session-l1-1-0.dll                                   | 3.0 kb
# api-ms-win-security-activedirectoryclient-l1-1-0.dll                   | 3.5 kb
# api-ms-win-security-appcontainer-l1-1-0.dll                            | 3.0 kb
# api-ms-win-security-audit-l1-1-0.dll                                   | 3.0 kb
# api-ms-win-security-audit-l1-1-1.dll                                   | 3.5 kb
# api-ms-win-security-base-l1-1-0.dll                                    | 5.5 kb
# api-ms-win-security-base-l1-2-0.dll                                    | 5.5 kb
# api-ms-win-security-base-private-l1-1-0.dll                            | 2.5 kb
# api-ms-win-security-base-private-l1-1-1.dll                            | 2.5 kb
# api-ms-win-security-credentials-l1-1-0.dll                             | 4.0 kb
# api-ms-win-security-credentials-l2-1-0.dll                             | 3.5 kb
# api-ms-win-security-cryptoapi-l1-1-0.dll                               | 4.0 kb
# api-ms-win-security-grouppolicy-l1-1-0.dll                             | 4.0 kb
# api-ms-win-security-logon-l1-1-0.dll                                   | 2.5 kb
# api-ms-win-security-lsalookup-l1-1-0.dll                               | 3.0 kb
# api-ms-win-security-lsalookup-l1-1-1.dll                               | 3.0 kb
# api-ms-win-security-lsalookup-l2-1-0.dll                               | 3.0 kb
# api-ms-win-security-lsalookup-l2-1-1.dll                               | 3.0 kb
# api-ms-win-security-lsapolicy-l1-1-0.dll                               | 3.5 kb
# api-ms-win-security-provider-l1-1-0.dll                                | 3.0 kb
# api-ms-win-security-sddl-ansi-l1-1-0.dll                               | 3.0 kb
# api-ms-win-security-sddl-l1-1-0.dll                                    | 2.5 kb
# api-ms-win-security-sddlparsecond-l1-1-0.dll                           | 3.0 kb
# api-ms-win-security-systemfunctions-l1-1-0.dll                         | 3.0 kb
# api-ms-win-security-trustee-l1-1-0.dll                                 | 3.0 kb
# api-ms-win-security-trustee-l1-1-1.dll                                 | 3.5 kb
# api-ms-win-service-core-l1-1-0.dll                                     | 2.5 kb
# api-ms-win-service-core-l1-1-1.dll                                     | 2.5 kb
# api-ms-win-service-management-l1-1-0.dll                               | 2.5 kb
# api-ms-win-service-management-l2-1-0.dll                               | 2.5 kb
# api-ms-win-service-private-l1-1-0.dll                                  | 3.0 kb
# api-ms-win-service-winsvc-l1-1-0.dll                                   | 3.5 kb
# api-ms-win-service-winsvc-l1-2-0.dll                                   | 3.0 kb
# api-ms-win-shcore-comhelpers-l1-1-0.dll                                | 3.0 kb
# api-ms-win-shcore-obsolete-l1-1-0.dll                                  | 3.0 kb
# api-ms-win-shcore-registry-l1-1-1.dll                                  | 3.5 kb
# api-ms-win-shcore-scaling-l1-1-0.dll                                   | 3.0 kb
# api-ms-win-shcore-scaling-l1-1-1.dll                                   | 3.5 kb
# api-ms-win-shcore-stream-l1-1-0.dll                                    | 3.5 kb
# api-ms-win-shcore-stream-winrt-l1-1-0.dll                              | 3.0 kb
# api-ms-win-shcore-sysinfo-l1-1-0.dll                                   | 3.0 kb
# api-ms-win-shcore-thread-l1-1-0.dll                                    | 3.0 kb
# api-ms-win-shcore-unicodeansi-l1-1-0.dll                               | 3.0 kb
# api-ms-win-shell-shellcom-l1-1-0.dll                                   | 3.0 kb
# api-ms-win-shell-shellfolders-l1-1-0.dll                               | 3.5 kb
# apisetschema.dll                                                       | 68.3 kb
# ApnDatabase.xml                                                        | 438.1 kb
# apphelp.dll                                                            | 551.0 kb
# Apphlpdm.dll                                                           | 33.5 kb
# appidapi.dll                                                           | 73.7 kb
# appidcertstorecheck.exe                                                | 17.5 kb
# appidpolicyconverter.exe                                               | 193.0 kb
# AppIdPolicyEngineApi.dll                                               | 295.5 kb
# appidsvc.dll                                                           | 39.0 kb
# appinfo.dll                                                            | 107.5 kb
# appmgmts.dll                                                           | 183.5 kb
# appmgr.dll                                                             | 448.5 kb
# appraiser.dll                                                          | 1564.5 kb
# AppReadiness.dll                                                       | 549.5 kb
# apprepapi.dll                                                          | 159.5 kb
# apprepsync.dll                                                         | 166.0 kb
# appsruprov.dll                                                         | 34.0 kb
# appwiz.cpl                                                             | 753.5 kb
# AppxAllUserStore.dll                                                   | 163.0 kb
# AppxApplicabilityEngine.dll                                            | 512.5 kb
# AppXDeploymentClient.dll                                               | 262.5 kb
# AppXDeploymentExtensions.dll                                           | 933.0 kb
# AppXDeploymentServer.dll                                               | 1316.5 kb
# AppxPackaging.dll                                                      | 556.5 kb
# AppxProvisioning.xml                                                   | 0.6 kb
# AppxSip.dll                                                            | 117.0 kb
# AppxStreamingDataSourcePS.dll                                          | 12.5 kb
# AppxSysprep.dll                                                        | 54.0 kb
# ARP.EXE                                                                | 24.5 kb
# asferror.dll                                                           | 2.0 kb
# aspnet_counters.dll                                                    | 32.0 kb
# asycfilt.dll                                                           | 89.5 kb
# at.exe                                                                 | 28.5 kb
# AtBroker.exe                                                           | 52.5 kb
# atl.dll                                                                | 106.0 kb
# atl100.dll                                                             | 154.8 kb
# atlthunk.dll                                                           | 47.0 kb
# atmfd.dll                                                              | 364.3 kb
# atmlib.dll                                                             | 43.0 kb
# attrib.exe                                                             | 20.0 kb
# audiodg.exe                                                            | 265.9 kb
# AudioEndpointBuilder.dll                                               | 221.0 kb
# AudioEng.dll                                                           | 471.6 kb
# AUDIOKSE.dll                                                           | 384.9 kb
# AudioSes.dll                                                           | 488.3 kb
# audiosrv.dll                                                           | 890.0 kb
# auditcse.dll                                                           | 203.0 kb
# AuditNativeSnapIn.dll                                                  | 218.0 kb
# auditpol.exe                                                           | 63.5 kb
# AuditPolicyGPInterop.dll                                               | 72.0 kb
# auditpolmsg.dll                                                        | 93.0 kb
# AuthBroker.dll                                                         | 130.0 kb
# AuthExt.dll                                                            | 36.0 kb
# authfwcfg.dll                                                          | 486.0 kb
# AuthFWGP.dll                                                           | 300.0 kb
# AuthFWSnapin.dll                                                       | 5000.0 kb
# AuthFWWizFwk.dll                                                       | 111.5 kb
# AuthHost.exe                                                           | 179.1 kb
# AuthHostProxy.dll                                                      | 19.0 kb
# authui.dll                                                             | 2714.0 kb
# authz.dll                                                              | 269.5 kb
# autochk.exe                                                            | 870.0 kb
# autoconv.exe                                                           | 904.0 kb
# autofmt.exe                                                            | 854.0 kb
# autoplay.dll                                                           | 148.5 kb
# AutoWorkplace.exe                                                      | 44.0 kb
# AutoWorkplace.exe.config                                               | 0.4 kb
# AutoWorkplaceN.dll                                                     | 9.0 kb
# avicap32.dll                                                           | 76.5 kb
# avifil32.dll                                                           | 114.0 kb
# avrt.dll                                                               | 34.8 kb
# AxInstSv.dll                                                           | 108.5 kb
# AxInstUI.exe                                                           | 58.5 kb
# azman.msc                                                              | 40.6 kb
# azroles.dll                                                            | 898.5 kb
# azroleui.dll                                                           | 443.0 kb
# AzSqlExt.dll                                                           | 31.5 kb
# baaupdate.exe                                                          | 109.5 kb
# backgroundTaskHost.exe                                                 | 10.0 kb
# BackgroundTransferHost.exe                                             | 31.5 kb
# basecsp.dll                                                            | 197.8 kb
# basesrv.dll                                                            | 58.0 kb
# batmeter.dll                                                           | 1975.5 kb
# bcd.dll                                                                | 92.8 kb
# bcdboot.exe                                                            | 161.5 kb
# bcdedit.exe                                                            | 341.0 kb
# bcdprov.dll                                                            | 81.0 kb
# bcdsrv.dll                                                             | 85.5 kb
# BCP47Langs.dll                                                         | 388.0 kb
# bcrypt.dll                                                             | 149.3 kb
# bcryptprimitives.dll                                                   | 387.9 kb
# bdaplgin.ax                                                            | 102.5 kb
# bdechangepin.exe                                                       | 346.0 kb
# BdeHdCfg.exe                                                           | 127.5 kb
# BdeHdCfgLib.dll                                                        | 105.5 kb
# bderepair.dll                                                          | 45.0 kb
# bdesvc.dll                                                             | 340.5 kb
# BdeSysprep.dll                                                         | 10.5 kb
# bdeui.dll                                                              | 33.0 kb
# BdeUISrv.exe                                                           | 53.0 kb
# bdeunlock.exe                                                          | 288.0 kb
# BFE.DLL                                                                | 825.5 kb
# bi.dll                                                                 | 23.5 kb
# bidispl.dll                                                            | 46.5 kb
# BioCredProv.dll                                                        | 317.5 kb
# bisrv.dll                                                              | 264.0 kb
# BitLockerDeviceEncryption.exe                                          | 101.0 kb
# BitLockerWizard.exe                                                    | 99.5 kb
# BitLockerWizardElev.exe                                                | 99.5 kb
# bitsadmin.exe                                                          | 224.0 kb
# bitsigd.dll                                                            | 53.0 kb
# bitsperf.dll                                                           | 24.0 kb
# bitsprx2.dll                                                           | 14.0 kb
# bitsprx3.dll                                                           | 14.0 kb
# bitsprx4.dll                                                           | 13.5 kb
# bitsprx5.dll                                                           | 34.5 kb
# bitsprx6.dll                                                           | 14.5 kb
# bitsprx7.dll                                                           | 15.0 kb
# biwinrt.dll                                                            | 136.5 kb
# blackbox.dll                                                           | 767.5 kb
# BlbEvents.dll                                                          | 75.5 kb
# blbres.dll                                                             | 2.0 kb
# blb_ps.dll                                                             | 29.5 kb
# BluetoothApis.dll                                                      | 105.0 kb
# boot.sdi                                                               | 3096.0 kb
# bootcfg.exe                                                            | 85.5 kb
# bootim.exe                                                             | 13.5 kb
# BootMenuUX.dll                                                         | 146.0 kb
# bootsect.exe                                                           | 106.3 kb
# bootstr.dll                                                            | 2.5 kb
# bootux.dll                                                             | 3239.5 kb
# BOOTVID.DLL                                                            | 24.8 kb
# bopomofo.uce                                                           | 22.4 kb
# brdgcfg.dll                                                            | 26.5 kb
# bridgeres.dll                                                          | 2.0 kb
# bridgeunattend.exe                                                     | 20.5 kb
# BrokerLib.dll                                                          | 130.0 kb
# browcli.dll                                                            | 57.0 kb
# browser.dll                                                            | 132.0 kb
# browseui.dll                                                           | 13.5 kb
# bthci.dll                                                              | 89.5 kb
# BthHFSrv.dll                                                           | 317.0 kb
# BthMtpContextHandler.dll                                               | 30.5 kb
# bthpanapi.dll                                                          | 31.0 kb
# BthpanContextHandler.dll                                               | 94.0 kb
# bthprops.cpl                                                           | 216.0 kb
# BthRadioMedia.dll                                                      | 65.5 kb
# bthserv.dll                                                            | 92.5 kb
# BthSQM.dll                                                             | 27.0 kb
# bthudtask.exe                                                          | 37.0 kb
# btpanui.dll                                                            | 72.0 kb
# Bubbles.scr                                                            | 770.0 kb
# BulkOperationHost.exe                                                  | 86.0 kb
# BWContextHandler.dll                                                   | 52.0 kb
# ByteCodeGenerator.exe                                                  | 33.0 kb
# cabinet.dll                                                            | 141.7 kb
# cabview.dll                                                            | 138.0 kb
# cacls.exe                                                              | 31.0 kb
# calc.exe                                                               | 912.0 kb
# CallButtons.dll                                                        | 95.0 kb
# CallButtons.ProxyStub.dll                                              | 23.0 kb
# CameraSettingsUIHost.exe                                               | 30.8 kb
# capiprovider.dll                                                       | 59.5 kb
# capisp.dll                                                             | 21.5 kb
# catsrv.dll                                                             | 477.0 kb
# catsrvps.dll                                                           | 52.0 kb
# catsrvut.dll                                                           | 510.0 kb
# cca.dll                                                                | 101.0 kb
# cdd.dll                                                                | 201.5 kb
# cdosys.dll                                                             | 1067.0 kb
# centel.dll                                                             | 459.0 kb
# cero.rs                                                                | 54.0 kb
# certca.dll                                                             | 945.5 kb
# certcli.dll                                                            | 435.0 kb
# certCredProvider.dll                                                   | 336.5 kb
# certenc.dll                                                            | 52.0 kb
# CertEnroll.dll                                                         | 2573.5 kb
# CertEnrollCtrl.exe                                                     | 54.0 kb
# CertEnrollUI.dll                                                       | 316.0 kb
# certlm.msc                                                             | 61.6 kb
# certmgr.dll                                                            | 2184.0 kb
# certmgr.msc                                                            | 61.6 kb
# CertPolEng.dll                                                         | 82.0 kb
# certprop.dll                                                           | 155.0 kb
# certreq.exe                                                            | 375.0 kb
# certutil.exe                                                           | 1262.0 kb
# cewmdm.dll                                                             | 263.5 kb
# cfgbkend.dll                                                           | 61.0 kb
# cfgmgr32.dll                                                           | 308.2 kb
# cfmifs.dll                                                             | 32.5 kb
# cfmifsproxy.dll                                                        | 14.5 kb
# change.exe                                                             | 16.5 kb
# changepk.exe                                                           | 57.0 kb
# charmap.exe                                                            | 161.5 kb
# chartv.dll                                                             | 131.0 kb
# chcp.com                                                               | 13.5 kb
# CheckNetIsolation.exe                                                  | 27.5 kb
# chglogon.exe                                                           | 21.5 kb
# chgport.exe                                                            | 23.5 kb
# chgusr.exe                                                             | 21.0 kb
# chkdsk.exe                                                             | 24.5 kb
# chkntfs.exe                                                            | 20.0 kb
# chkwudrv.dll                                                           | 24.0 kb
# choice.exe                                                             | 33.0 kb
# CHxReadingStringIME.dll                                                | 12.5 kb
# ci.dll                                                                 | 519.2 kb
# cic.dll                                                                | 198.0 kb
# cipher.exe                                                             | 43.0 kb
# CIRCoInst.dll                                                          | 10.5 kb
# clb.dll                                                                | 17.5 kb
# clbcatq.dll                                                            | 713.7 kb
# cleanmgr.exe                                                           | 212.5 kb
# clfsw32.dll                                                            | 73.5 kb
# cliconfg.dll                                                           | 84.5 kb
# cliconfg.exe                                                           | 29.5 kb
# cliconfg.rll                                                           | 36.0 kb
# clip.exe                                                               | 29.0 kb
# CloudNotifications.exe                                                 | 44.4 kb
# CloudStorageWizard.exe                                                 | 138.5 kb
# clrhost.dll                                                            | 14.5 kb
# clusapi.dll                                                            | 422.0 kb
# cmcfg32.dll                                                            | 36.5 kb
# cmd.exe                                                                | 349.0 kb
# cmdext.dll                                                             | 12.5 kb
# cmdial32.dll                                                           | 505.0 kb
# cmdkey.exe                                                             | 16.5 kb
# cmdl32.exe                                                             | 50.5 kb
# cmifw.dll                                                              | 94.5 kb
# cmipnpinstall.dll                                                      | 236.5 kb
# cmlua.dll                                                              | 43.5 kb
# cmmon32.exe                                                            | 41.0 kb
# cmpbk32.dll                                                            | 28.5 kb
# cmstp.exe                                                              | 91.5 kb
# cmstplua.dll                                                           | 19.5 kb
# cmutil.dll                                                             | 56.5 kb
# cngcredui.dll                                                          | 103.0 kb
# cngprovider.dll                                                        | 63.0 kb
# cnvfat.dll                                                             | 38.5 kb
# cob-au.rs                                                              | 40.0 kb
# cofire.exe                                                             | 22.5 kb
# cofiredm.dll                                                           | 31.5 kb
# colbact.dll                                                            | 80.0 kb
# COLORCNV.DLL                                                           | 198.3 kb
# colorcpl.exe                                                           | 85.0 kb
# colorui.dll                                                            | 610.0 kb
# combase.dll                                                            | 2125.6 kb
# comcat.dll                                                             | 9.0 kb
# comctl32.dll                                                           | 638.5 kb
# comdlg32.dll                                                           | 700.5 kb
# comexp.msc                                                             | 121.2 kb
# comp.exe                                                               | 24.5 kb
# compact.exe                                                            | 20.0 kb
# CompatTelRunner.exe                                                    | 146.1 kb
# compmgmt.msc                                                           | 110.6 kb
# CompMgmtLauncher.exe                                                   | 88.5 kb
# CompPkgSup.dll                                                         | 19.7 kb
# compstui.dll                                                           | 302.5 kb
# ComputerDefaults.exe                                                   | 37.0 kb
# comrepl.dll                                                            | 111.5 kb
# comres.dll                                                             | 1267.0 kb
# comsnap.dll                                                            | 290.5 kb
# comsvcs.dll                                                            | 1666.0 kb
# comuid.dll                                                             | 838.5 kb
# concrt140.dll                                                          | 325.8 kb
# ConfigureExpandedStorage.dll                                           | 66.0 kb
# conhost.exe                                                            | 353.0 kb
# connect.dll                                                            | 1333.0 kb
# ConnectedAccountState.dll                                              | 49.0 kb
# connectedsearch-appcmd.searchconnector-ms                              | 0.5 kb
# connectedsearch-contacts.searchconnector-ms                            | 0.5 kb
# connectedsearch-history.searchconnector-ms                             | 0.5 kb
# connectedsearch-music.searchconnector-ms                               | 0.5 kb
# connectedsearch-paths.searchconnector-ms                               | 0.5 kb
# ...
# wlansvcpal.dll                                                         | 18.5 kb
# wlanui.dll                                                             | 398.0 kb
# wlanutil.dll                                                           | 3.0 kb
# Wldap32.dll                                                            | 350.5 kb
# wldp.dll                                                               | 43.9 kb
# wlgpclnt.dll                                                           | 111.5 kb
# wlidcli.dll                                                            | 763.5 kb
# wlidcredprov.dll                                                       | 290.5 kb
# wlidfdp.dll                                                            | 111.5 kb
# wlidnsp.dll                                                            | 72.5 kb
# wlidprov.dll                                                           | 455.0 kb
# wlidres.dll                                                            | 19.5 kb
# wlidsvc.dll                                                            | 1601.0 kb
# wlrmdr.exe                                                             | 58.0 kb
# WlS0WndH.dll                                                           | 11.5 kb
# WMADMOD.DLL                                                            | 1181.8 kb
# WMADMOE.DLL                                                            | 1123.3 kb
# WMALFXGFXDSP.dll                                                       | 1756.3 kb
# WMASF.DLL                                                              | 285.8 kb
# wmcodecdspps.dll                                                       | 13.0 kb
# wmdmlog.dll                                                            | 38.5 kb
# wmdmps.dll                                                             | 111.0 kb
# wmdrmdev.dll                                                           | 566.4 kb
# wmdrmnet.dll                                                           | 448.0 kb
# wmdrmsdk.dll                                                           | 595.5 kb
# wmerror.dll                                                            | 2.0 kb
# wmi.dll                                                                | 5.5 kb
# wmiclnt.dll                                                            | 37.5 kb
# wmicmiplugin.dll                                                       | 496.5 kb
# wmidcom.dll                                                            | 163.0 kb
# wmidx.dll                                                              | 191.5 kb
# WmiMgmt.msc                                                            | 141.3 kb
# wmiprop.dll                                                            | 29.0 kb
# wmitomi.dll                                                            | 202.0 kb
# WMNetMgr.dll                                                           | 1259.0 kb
# wmp.dll                                                                | 15070.0 kb
# WMPDMC.exe                                                             | 1800.5 kb
# WmpDui.dll                                                             | 365.5 kb
# wmpdxm.dll                                                             | 230.0 kb
# wmpeffects.dll                                                         | 708.7 kb
# WMPhoto.dll                                                            | 393.0 kb
# wmploc.DLL                                                             | 9104.5 kb
# wmpmde.dll                                                             | 1474.3 kb
# wmpps.dll                                                              | 436.8 kb
# wmpshell.dll                                                           | 125.5 kb
# wmsgapi.dll                                                            | 16.5 kb
# WMSPDMOD.DLL                                                           | 987.0 kb
# WMSPDMOE.DLL                                                           | 1625.0 kb
# WMVCORE.DLL                                                            | 3065.2 kb
# WMVDECOD.DLL                                                           | 2680.8 kb
# wmvdspa.dll                                                            | 201.0 kb
# WMVENCOD.DLL                                                           | 2392.8 kb
# WMVSDECD.DLL                                                           | 544.8 kb
# WMVSENCD.DLL                                                           | 440.5 kb
# WMVXENCD.DLL                                                           | 629.5 kb
# WofTasks.dll                                                           | 28.0 kb
# WofUtil.dll                                                            | 18.0 kb
# workerdd.dll                                                           | 14.0 kb
# WorkFolders.exe                                                        | 133.0 kb
# WorkfoldersControl.dll                                                 | 769.0 kb
# WorkFoldersGPExt.dll                                                   | 65.0 kb
# WorkFoldersRes.dll                                                     | 115.0 kb
# WorkFoldersShell.dll                                                   | 189.0 kb
# workfolderssvc.dll                                                     | 1629.0 kb
# wow64.dll                                                              | 278.5 kb
# wow64cpu.dll                                                           | 13.0 kb
# wow64win.dll                                                           | 403.5 kb
# wowreg32.exe                                                           | 16.5 kb
# Wpc.dll                                                                | 3180.0 kb
# wpccpl.dll                                                             | 2812.5 kb
# WpcMon.exe                                                             | 3045.0 kb
# WpcNBModel.bin                                                         | 1485.2 kb
# wpcsvc.dll                                                             | 12.0 kb
# WpcWebSync.dll                                                         | 2873.0 kb
# wpdbusenum.dll                                                         | 85.0 kb
# wpdshext.dll                                                           | 2019.5 kb
# WPDShextAutoplay.exe                                                   | 30.5 kb
# WPDShServiceObj.dll                                                    | 107.5 kb
# WPDSp.dll                                                              | 359.0 kb
# wpd_ci.dll                                                             | 601.5 kb
# wpnapps.dll                                                            | 363.0 kb
# wpncore.dll                                                            | 592.5 kb
# wpninprc.dll                                                           | 61.0 kb
# wpnpinst.exe                                                           | 21.0 kb
# wpnprv.dll                                                             | 203.5 kb
# wpnsruprov.dll                                                         | 26.0 kb
# write.exe                                                              | 11.0 kb
# ws2help.dll                                                            | 4.5 kb
# ws2_32.dll                                                             | 354.6 kb
# wscapi.dll                                                             | 173.5 kb
# wscinterop.dll                                                         | 167.0 kb
# wscisvif.dll                                                           | 24.5 kb
# WSClient.dll                                                           | 201.5 kb
# WSCollect.exe                                                          | 83.0 kb
# wscproxystub.dll                                                       | 14.5 kb
# wscript.exe                                                            | 168.0 kb
# wscsvc.dll                                                             | 143.5 kb
# wscui.cpl                                                              | 1125.0 kb
# WSDApi.dll                                                             | 643.0 kb
# wsdchngr.dll                                                           | 29.5 kb
# WSDMon.dll                                                             | 302.5 kb
# WSDPrintProxy.DLL                                                      | 76.0 kb
# WSDScanProxy.dll                                                       | 69.0 kb
# wsecedit.dll                                                           | 1444.5 kb
# wsepno.dll                                                             | 30.0 kb
# wshbth.dll                                                             | 62.0 kb
# wshcon.dll                                                             | 24.0 kb
# wshelper.dll                                                           | 20.0 kb
# wshext.dll                                                             | 104.0 kb
# wship6.dll                                                             | 12.0 kb
# wshirda.dll                                                            | 14.0 kb
# wshnetbs.dll                                                           | 13.5 kb
# wshom.ocx                                                              | 148.0 kb
# wshqos.dll                                                             | 18.5 kb
# wshrm.dll                                                              | 17.5 kb
# WSHTCPIP.DLL                                                           | 12.0 kb
# WsmAgent.dll                                                           | 31.0 kb
# wsmanconfig_schema.xml                                                 | 4.6 kb
# WSManHTTPConfig.exe                                                    | 29.5 kb
# WSManMigrationPlugin.dll                                               | 69.0 kb
# WsmAuto.dll                                                            | 158.5 kb
# wsmplpxy.dll                                                           | 15.5 kb
# wsmprovhost.exe                                                        | 31.0 kb
# WsmPty.xsl                                                             | 1.5 kb
# WsmRes.dll                                                             | 59.0 kb
# WsmSvc.dll                                                             | 2548.5 kb
# WsmTxt.xsl                                                             | 2.4 kb
# WsmWmiPl.dll                                                           | 278.5 kb
# wsnmp32.dll                                                            | 63.0 kb
# wsock32.dll                                                            | 17.0 kb
# wsqmcons.exe                                                           | 374.0 kb
# WSReset.exe                                                            | 78.0 kb
# WSService.dll                                                          | 3379.4 kb
# WSShared.dll                                                           | 949.0 kb
# WSSync.dll                                                             | 198.5 kb
# WSTPager.ax                                                            | 103.5 kb
# wtsapi32.dll                                                           | 62.5 kb
# wu.upgrade.ps.dll                                                      | 15.0 kb
# wuaext.dll                                                             | 17.0 kb
# wuapi.dll                                                              | 876.0 kb
# wuapp.exe                                                              | 35.0 kb
# wuauclt.exe                                                            | 133.7 kb
# wuaueng.dll                                                            | 3630.5 kb
# wucltux.dll                                                            | 2188.0 kb
# WUDFCoinstaller.dll                                                    | 46.5 kb
# WUDFHost.exe                                                           | 299.0 kb
# WUDFPlatform.dll                                                       | 220.5 kb
# WUDFSvc.dll                                                            | 102.5 kb
# WUDFx.dll                                                              | 878.5 kb
# WUDFx02000.dll                                                         | 621.5 kb
# wudriver.dll                                                           | 93.5 kb
# wups.dll                                                               | 64.5 kb
# wups2.dll                                                              | 51.0 kb
# wusa.exe                                                               | 302.5 kb
# WUSettingsProvider.dll                                                 | 399.5 kb
# wushareduxresources.dll                                                | 97.0 kb
# wuwebv.dll                                                             | 137.0 kb
# wvc.dll                                                                | 577.0 kb
# WwaApi.dll                                                             | 192.0 kb
# WWAHost.exe                                                            | 707.5 kb
# WWanAPI.dll                                                            | 508.3 kb
# wwancfg.dll                                                            | 54.0 kb
# wwanconn.dll                                                           | 445.0 kb
# WWanHC.dll                                                             | 72.5 kb
# wwaninst.dll                                                           | 20.5 kb
# wwanmm.dll                                                             | 1129.5 kb
# Wwanpref.dll                                                           | 49.5 kb
# wwanprotdim.dll                                                        | 71.0 kb
# WwanRadioManager.dll                                                   | 61.5 kb
# wwansvc.dll                                                            | 501.5 kb
# wwapi.dll                                                              | 62.0 kb
# XAudio2_8.dll                                                          | 286.5 kb
# xcopy.exe                                                              | 47.5 kb
# XInput1_4.dll                                                          | 35.5 kb
# XInput9_1_0.dll                                                        | 10.0 kb
# xmlfilter.dll                                                          | 57.0 kb
# xmllite.dll                                                            | 225.4 kb
# xmlprovi.dll                                                           | 21.0 kb
# xolehlp.dll                                                            | 60.0 kb
# XpsFilt.dll                                                            | 919.0 kb
# XpsGdiConverter.dll                                                    | 458.0 kb
# XpsPrint.dll                                                           | 1874.5 kb
# XpsRasterService.dll                                                   | 203.5 kb
# xpsrchvw.exe                                                           | 4580.5 kb
# xpsrchvw.xml                                                           | 74.3 kb
# xpsservices.dll                                                        | 2984.5 kb
# XPSSHHDR.dll                                                           | 99.5 kb
# xpssvcs.dll                                                            | 1467.0 kb
# xwizard.dtd                                                            | 3.9 kb
# xwizard.exe                                                            | 60.5 kb
# xwizards.dll                                                           | 465.5 kb
# xwreg.dll                                                              | 116.0 kb
# xwtpdui.dll                                                            | 257.0 kb
# xwtpw32.dll                                                            | 142.0 kb
# zipfldr.dll                                                            | 430.0 kb

# %%
data=" "
folder="c:/windows/system32/"
files=os.listdir(folder)
for item in files:
    fullpath=os.path.join(folder,item)
    if os.path.isfile(fullpath):
        sz=os.path.getsize(fullpath)
        out=f'{item.ljust(70)} | {sz/1024 :.1f} kb'
        data +=out+"\n"

# %%
from dputils import files   # tis function

# %%
files.save_data('dlls.txt',data)
# Out:
# True
