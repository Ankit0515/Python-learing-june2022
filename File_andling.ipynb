# %% [markdown]
# Reading file

# %%
x= lambda a,b,c: a*b*c
x(2,3,4)
print(x)
# Out:
# <function <lambda> at 0x000001597C4B9820>

# %%
f=open("example.py")  #load file into variable
content = f.read() # read the file
f.close()  # close file

# %%
f=open("example.py")  #load file into variable
content = f.read() # read the file

# %%
print(content)
# Out:
# from turtle import *
# s= getscreen()
# t=turtle
# mainloop ()

# %%
f1=open(r"C:/Users/Ankit Shrivastava/Downloads/Piling and MMS.xlsx")
con=f.read()
print(con)

# %%
with open('example.py') as file:
    print(file.read())
# Out:
# from turtle import *
# s= getscreen()
# t=turtle
# mainloop ()

# %%
f3=open(r'C:\Users\Ankit Shrivastava\Downloads\20200713_002800.jpg','rb')

# %%
print(f3.read())
f.close()
# Out:
# b'\xff\xd8\xff\xe1\x03gExif\x00\x00MM\x00*\x00\x00\x00\x08\x00\r\x01\x01\x00\x04\x00\x00\x00\x01\x00\x00\x04\xe1\x01\x0f\x00\x02\x00\x00\x00\x08\x00\x00\x00\xaa\x01\x12\x00\x03\x00\x00\x00\x01\x00\x00\x00\x00\x012\x00\x02\x00\x00\x00\x14\x00\x00\x00\xb2\x88%\x00\x04\x00\x00\x00\x01\x00\x00\x02\x9b\x01\x1b\x00\x05\x00\x00\x00\x01\x00\x00\x00\xc6\x01\x1a\x00\x05\x00\x00\x00\x01\x00\x00\x00\xce\x01\x00\x00\x04\x00\x00\x00\x01\x00\x00\x03\xe2\x01\x10\x00\x02\x00\x00\x00\t\x00\x00\x00\xd6\x011\x00\x02\x00\x00\x00\x0e\x00\x00\x00\xdf\x02\x13\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\x87i\x00\x04\x00\x00\x00\x01\x00\x00\x00\xed\x01(\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x00\x00\x03\x01samsung\x002020:07:13 24:28:01\x00\x00\x00\x00H\x00\x00\x00\x01\x00\x00\x00H\x00\x00\x00\x01SM-A505F\x00A505FDDS5BTF2\x00\x00\x19\x92\x02\x00\x05\x00\x00\x00\x01\x00\x00\x02\x1f\x90\x00\x00\x07\x00\x00\x00\x040220\x92\x04\x00\n\x00\x00\x00\x01\x00\x00\x02\'\x88"\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\xa0\x01\
# ...

# %% [markdown]
# WRITING CONTENT IN FILE

# %%
kahani ="one upon a time, there was planet that was green , an blue , the end"
file= open('kahani.txt','w')
file.write(kahani)
file.close()  #save the file

# %%
info=input("enter te info:")
with open ('info.txt','w') as f:
    f.write(info)
    f.write("\n")
    f.write("autor\n")
    f.write("Ankit")

# %%
data=input("enter the content")
with open("kahani1.txt",'a') as f:
    f.write("\n"+data)

# %%
from dputils import files

# %%
content=files.get_data(r'G:\second innings\duptil.txt')

# %%
print(content)
# Out:
# Project description
# A python library which can be used to extraxct data from files, pdfs, doc(x) files, as well as save data into these files. This library can be used to scrape and extract webpage data from websites as well.
#
# Installation Requirements and Instructions
# Python versions 3.8 or above should be installed. After that open your terminal: For windows users:
#
# pip install dputils
# For Mac/Linux users:
#
# pip3 install dputils
# Files Modules
# Functions from dputils.files:
#
# get_data:
#
# To import, use statement:
# from dputils.files import get_data
# Obtains data from files of any extension given as args(supports text files, binary files, pdf, doc for now, more coming!)
# sample call:
# content = get_data(r"sample.docx")
# print(content)
# Returns a string or binary data depending on the output arg
# images will not be extracted
# save_data:
#
# To import, use statement:
# from dputils.files import save_data
# ...
